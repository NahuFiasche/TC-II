# %% [markdown]
# # Teoría de los Circuitos II - R4001  #
# # Tarea Semanal 1 - Fiasche Nahuel #

# %% [markdown]
# ## Cálculo y Análisis de la Transferencia Analíticamente (puntos 1, 2 y 3) ##
#
# A continuación, se adjunta en formato PDF los ejs 1,2 y 3.

# %%
from IPython.display import IFrame
IFrame("./Puntos 1,2,3.pdf", width=1000, height=900)
# Out:
#         <iframe
#             width="1000"
#             height="900"
#             src="./Puntos 1,2,3.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ## 4) Simulación de la Transferencia Normalizada

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on Sat Apr  8 13:48:47 2023

@author: nahu
"""

# Librerías externas NumPy, SciPy y Matplotlib
from scipy.signal import TransferFunction
import matplotlib.pyplot as plt
import numpy as np

from pytc2.sistemas_lineales import pzmap, GroupDelay, bodePlot

# Asigno valores a R2 y R1 (La consigna no aclara con que valores simular)
R2_lista = [1, 2, 3]
R1 = 2

plt.close('all')

for i in range(len(R2_lista)):
    
    Tf = TransferFunction( [1,-R2_lista[i]/R1], [1, 1] )

    bodePlot(Tf, fig_id=1, filter_description = 'R2/R1 = {}'.format(R2_lista[i]/R1) )

    pzmap(Tf, fig_id=2, filter_description = 'R2/R1 = {}'.format(R2_lista[i]/R1)) #S plane pole/zero plot

    GroupDelay(Tf, fig_id=3, filter_description = 'R2/R1 = {}'.format(R2_lista[i]/R1))

# %% [markdown]
# ## 5) Simulación de la Transferencia utilizando los valores otorgados

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on Sat Apr  8 13:48:47 2023

@author: nahu
"""

# Librerías externas NumPy, SciPy y Matplotlib
from scipy.signal import TransferFunction
import matplotlib.pyplot as plt
import numpy as np

from pytc2.sistemas_lineales import pzmap, GroupDelay, bodePlot

R1 = 1e3
R2 = 1e3
R3 = 1e3
C1 = 1e-6
    
Tf = TransferFunction( [1,-R2/(C1*R1*R3)], [1, 1/(C1*R3)] )

plt.close('all')

bodePlot(Tf, fig_id=1, filter_description = 'R1 = {} K\n R2 = {} K\n R3 = {} K\nC1 = {:.1f} uF'.format(R1/1000,R2/1000,R3/1000,C1/1e-6) )

pzmap(Tf, fig_id=2, filter_description = 'R1 = {} K\n R2 = {} K\n R3 = {} K\nC1 = {:.1f} uF'.format(R1/1000,R2/1000,R3/1000,C1/1e-6)) 

GroupDelay(Tf, fig_id=3, filter_description = 'R1 = {} K\n R2 = {} K\n R3 = {} K\nC1 = {:.1f} uF'.format(R1/1000,R2/1000,R3/1000,C1/1e-6))
# Out:
# (3,
#  <Axes: title={'center': 'Group delay'}, xlabel='Angular frequency [rad/sec]', ylabel='Group Delay [sec]'>)

# %% [markdown]
# ## 6) ¿Cuál puede ser la utilidad del Circuito?
# El circuito analizado es claramente un Filtro Pasabanda, con una ganancia para baja frecuencia regulable mediante los valores de R1 y R2.
# De la respuesta de fase, se observa que para bajas frecuencias, el circuito desfaza la señal 90 grados. Además, comparando con la respuesta de fase normalizada, se observa que para wo, la respuesta de fase es exactamente 45°.
#
# A partir de lo analizado, el circuito presentado podría servir para desfazar 90 grados una señal, sin modificar la amplitud. Por ejemplo, se podría utilizar a la salida de amplificador operacional inversor, para contrarrestar el efecto inversor que el mismo presenta en su salida.
