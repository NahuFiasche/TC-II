# %% [markdown]
# # Teoría de los Circuitos II - R4001  #
# # Tarea Semanal 4 - Fiasche Nahuel #

# %% [markdown]
# # Cálculo Analítico
# A continuación, se adjunta en formato PDF todos los cálculos analíticos, a saber:
# <ul>
#   <li>Cálculo de la Transferencia, usando la normalización "W butter"</li>
#   <li>Normalización de la Transferencia</li>
#   <li>Diagrama de Polos y Ceros del Pasa Bajos prototipo y del Pasa Altos requerido</li>
#   <li>Bosquejo aproximado del módulo de la transferencia</li>
#   <li>Implementación de la Red (pasiva pura) Normalizada</li>
#   <li>Implementación de la Red normalizada, utilizando un GIC de Antoniu para reemplazar los inductores</li>
#
#
# </ul>

# %%
from IPython.display import IFrame
IFrame("./TS4.pdf", width=1000, height=900)
# Out:
#         <iframe
#             width="1000"
#             height="900"
#             src="./TS4.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# # Simulación Numérica (Normalizada)

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on Wed May 17 16:40:35 2023

@author: nahu
"""

# Librerías externas NumPy, SciPy y Matplotlib
from scipy.signal import TransferFunction
import matplotlib.pyplot as plt
import numpy as np

from pytc2.sistemas_lineales import pzmap, GroupDelay, bodePlot, analyze_sys

den = np.polymul([1, 0.794], [1, 0.794, 0.794**2])

num = [1, 0, 0, 0]

Tf = TransferFunction(num,den)

analyze_sys( Tf, 'Ej 5.13' )

# %% [markdown]
# # Simulación Circuital de la Implementación Pasiva Normalizada
# La implementación pasiva a simular se adjunta a continuación.
#
# ![image.png](attachment:image.png)
#
# Las simulaciones obtenidas se encuentran a continuación.
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# # Simulación Circuital de la Implementación Activa (GIC de Antoniu)
# La implementación activa a simular se adjunta a continuación.
#
# ![image-4.png](attachment:image-4.png)
#
# Las simulaciones obtenidas se encuentran a continuación
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# # Simulación Circuital de la Implementación Activa (GIC de Antoniu) Desnormalizada
# La implementación activa a simular se adjunta a continuación.
#
# ![image-4.png](attachment:image-4.png)
#
# Las simulaciones obtenidas se encuentran a continuación
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # Conclusiones
#
# Se observa que la respuesta de módulo de la transferencia Pasa Altos normalizada, obtenida a partir de la simulación numérica, coincide con la simulada circuitalmente.
# También se destaca que en ambas implementaciones, las ganancias en 0.25 (rad/seg) y 1 (rad/seg) son de -30 db y -1 db respectivamente, lo que verifica que el circuito hallado cumple con los requerimientos establecidos por la plantilla.
#
# Por otro lado, se destaca que al utilizar el GIC de Antoniu para reemplazar el inductor de la transferencia SOS, la transferencia obtenida es exactamente igual, con la ventaja de estar conformado únicamente por resistores, capacitores y operacionales.
# Se concluye entonces que las dos implementaciones diseñadas satisfacen los requerimientos planteados por el enunciado.
