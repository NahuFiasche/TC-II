# %% [markdown]
# # Teoría de los Circuitos II - R4001  #
# # Tarea Semanal 13 - Fiasche Nahuel #

# %% [markdown]
# # Cálculo Analítico
# A continuación, se adjunta en formato PDF todos los cálculos analíticos referidos a la Tarea Semanal 13. Para el cálculo analítico, se utilizó las herramientas simbólicas provistas por la cátedra, a fin de facilitar los cálculos requeridos para el cálculo de la transferencia.

# %%
from IPython.display import IFrame
IFrame("./TS13.pdf", width=1000, height=900)
# Out:
#         <iframe
#             width="1000"
#             height="900"
#             src="./TS13.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# # Cálculo Simbólico

# %%
# ----- Librerías -------
import sympy as sp
import numpy as np
from pytc2.general import print_latex, print_subtitle, a_equal_b_latex_s
from pytc2.remociones import modsq2mod_s

# ---- Definición de Variable Compleja $
s = sp.symbols('s ', complex=True)

# Definición de S21 = T($) 
S21 = sp.Rational('15')/(s**3 + sp.Rational('6')*s**2 + sp.Rational('15')*s + sp.Rational('15') )
print_latex(a_equal_b_latex_s('S21(s)', S21))

# Cálculo de |S21|² = S21($) * S21(-$)
S21_sq = (S21 * S21.subs(s, -s)) 
print_latex(a_equal_b_latex_s('|S21|(s)²', S21_sq))

# Cálculo de |S11|² = 1 - |S21|², por condición de Darlington
S11_sq = sp.factor( 1 - S21_sq )
print_latex(a_equal_b_latex_s('|S11|²(s)', S11_sq))

# Cálculo de S11
S11 = modsq2mod_s(S11_sq)
print_latex(a_equal_b_latex_s('S11(s)', S11))

#Cálculo de Z1
Z1 = sp.simplify(sp.expand(sp.simplify(sp.expand(1+S11))/sp.simplify(sp.expand((1-S11)))))

print_latex(a_equal_b_latex_s('Z1(s)', Z1))
# Out:
# $\displaystyle S21(s)=\frac{15}{s^{3} + 6 s^{2} + 15 s + 15}$
# $\displaystyle |S21|(s)²=\frac{225}{\left(- s^{3} + 6 s^{2} - 15 s + 15\right) \left(s^{3} + 6 s^{2} + 15 s + 15\right)}$
# $\displaystyle |S11|²(s)=\frac{s^{2} \left(s^{4} - 6 s^{2} + 45\right)}{\left(s^{3} - 6 s^{2} + 15 s - 15\right) \left(s^{3} + 6 s^{2} + 15 s + 15\right)}$
# $\displaystyle S11(s)=\frac{s \left(s^{2} + 2 \sqrt{3} \cdot \sqrt[4]{5} s \cos{\left(\frac{\operatorname{atan}{\left(2 \right)}}{2} \right)} + 3 \sqrt{5}\right)}{s^{3} + 6 s^{2} + 15 s + 15}$
# $\displaystyle Z1(s)=\frac{2 s^{3} + 2 \sqrt{3} \cdot \sqrt[4]{5} s^{2} \cos{\left(\frac{\operatorname{atan}{\left(2 \right)}}{2} \right)} + 6 s^{2} + 3 \sqrt{5} s + 15 s + 15}{- 2 \sqrt{3} \cdot \sqrt[4]{5} s^{2} \cos{\left(\frac{\operatorname{atan}{\left(2 \right)}}{2} \right)} + 6 s^{2} - 3 \sqrt{5} s + 15 s + 15}$

# %% [markdown]
# # Simulación Circuital Normalizada
# A continuación, se adjunta el circuito normalizado simulado. Además, se visualiza la respuesta de módulo y fase de los parámetros S11 y S21
# ![image-4.png](attachment:image-4.png)
# ![image-5.png](attachment:image-5.png)

# %% [markdown]
# # Simulación Circuital Desnormalizada
# A continuación, se adjunta el circuito desnormalizado simulado. Además, se visualiza la respuesta de módulo y fase de los parámetros S11 y S21
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # Conclusiones
# Analizando la respuesta de Módulo y Fase obtenidas, es decir, el parámetro S21, se observa que el comportamiento corresponde a un filtro Bessel de 3er orden.
# Por otro lado, analizando el comportamiento de S11 se observa:
# * En el centro de la banda de paso, el cuadripolo refleja casi toda la potencia, ya que el valor de S11 es 0 db, es decir, unitario.
# * En la frecuencia de corte, S11 y S21 son iguales. Por lo tanto, en este punto la mitad de la potencia es transmitida, en cuanto la otra mitad de la potencia es reflejada al generador.
# * Para frecuencias muy altas, en la banda de detenida, el valor de S11 tiende a 0. Es decir, para frecuencias en dicho intervalo, el cuadripolo se encuentra adaptado.
