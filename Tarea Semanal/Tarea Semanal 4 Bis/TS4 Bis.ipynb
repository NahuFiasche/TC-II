# %% [markdown]
# # Teoría de los Circuitos II - R4001  #
# # Tarea Semanal 4 Bis - Fiasche Nahuel #

# %% [markdown]
# # Cálculo Analítico
# A continuación, se adjunta en formato PDF todos los cálculos analíticos, a saber:
# <ul>
#   <li>Cálculo de la Transferencia Normalizada</li>
#   <li>Diagrama aproximado de Polos y Ceros</li>
#   <li>Bosquejo aproximado del módulo de la transferencia</li>
#   <li>Implementación de la Red Normalizada utilizando estructuras Ackerberg Mosberg</li>
#
#
# </ul>

# %%
from IPython.display import IFrame
IFrame("./TS4_Bis.pdf", width=1000, height=900)
# Out:
#         <iframe
#             width="1000"
#             height="900"
#             src="./TS4_Bis_Bis.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# # Cálculos Simbólicos y Simulación Numérica (Normalizada)

# %%
# Módulos externos

import sympy as sp
from sympy.abc import s
# Ahora importamos las funciones de PyTC2

from pytc2.sistemas_lineales import analyze_sys, parametrize_sos, pretty_print_lti, pretty_print_bicuad_omegayq, tf2sos_analog, pretty_print_SOS
from pytc2.general import print_latex, print_subtitle
import numpy as np
import scipy.signal as sig
from IPython.display import display, Markdown

# Librerías externas NumPy, SciPy y Matplotlib
from scipy.signal import TransferFunction
import matplotlib.pyplot as plt
import numpy as np
from pytc2.sistemas_lineales import pzmap, GroupDelay, bodePlot, analyze_sys


# coeficientes de la transferencia Pasabajos Prototipo
Tlp_num = np.array([3.16])
den_aux = np.polymul([1, 1], [1, 1, 1])
Tlp_den = np.array(den_aux)

# Q de la transformación
Q_bp = 20/9

# Transformación y Visualización de Pasabajos Prototipo a Pasabanda Requerido
num_pbanda, den_pbanda = sig.lp2bp(Tlp_num, Tlp_den, bw = 1/Q_bp)

display(Markdown('### Filtro pasabanda de Orden 6 normalizado' ))

pretty_print_lti(num_pbanda, den_pbanda)

#Factorización y Visualización
sos_Tf = tf2sos_analog(num_pbanda, den_pbanda)

display(Markdown('### Filtro pasabanda de Orden 6 Factorizado y Normalizado' ))

pretty_print_SOS(sos_Tf)

# Simulación Numérica

display(Markdown('### Simulación Numérica' ))

Tf = TransferFunction(num_pbanda,den_pbanda)

analyze_sys( sos_Tf, 'TS4 Bis' )
# Out:
# ### Filtro pasabanda de Orden 6 normalizado
# $\displaystyle \frac{s^3 \,\, 0.288 }{s^6 + s^5 \,\, 0.9 + s^4 \,\, 3.405 + s^3 \,\, 1.891 + s^2 \,\, 3.405 + s \,\, 0.9 +   1 }$
# ### Filtro pasabanda de Orden 6 Factorizado y Normalizado
# $\displaystyle   \frac{s \,\, 1.452 }{s^2 + s \,\, 0.45 +   1 } . \frac{s \,\, 0.3382 }{s^2 + s \,\, 0.2683 + 1.476 } . \frac{s \,\, 0.5864 }{s^2 + s \,\, 0.1817 + 0.6773 }$
# ### Simulación Numérica

# %% [markdown]
# # Simulación Circuital de la Implementación Activa Normalizada
# La implementación activa a simular se adjunta a continuación.
#
# ![image.png](attachment:image.png)
#
# Las simulaciones obtenidas se encuentran a continuación.
#
# ![image-4.png](attachment:image-4.png)
#
# ![image-5.png](attachment:image-5.png)
#
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# # Simulación Circuital de la Implementación Activa Desnormalizada
# La implementación activa desnormalizada a simular se adjunta a continuación.
#
# ![image.png](attachment:image.png)
#
# Las simulaciones obtenidas se encuentran a continuación.
#
# ![image-3.png](attachment:image-3.png)
#
# ![image-5.png](attachment:image-5.png)
#
# ![image-4.png](attachment:image-4.png)

# %% [markdown]
# # Conclusiones
#
# Se observa que la respuesta de módulo de la transferencia Pasa Banda normalizada, obtenida a partir de la simulación numérica, coincide con la simulada circuitalmente.
# También se destaca que en la implementación normalizada la ganancia en el límite de la banda de paso es de 7 dB, y la ganancia en el inicio de la banda de detenida es de -10 dB, lo que verifica que el circuito implementado responde a la transferencia requerida.
#
# Por otro lado, se destaca que al incorporar una ganancia de 10 dB en la banda de paso, la ganancia en la banda de detenida se ve incrementada 10 dB, pasando de -20 dB a -10 dB. El enunciado es ambiguo, y no aclara si la atenuación requerida es considerando o no la ganancia en la banda de paso. De todas formas, de requerirse efectivamente una atenuación de 20 dB en la banda de detenida y una ganancia de 10 dB en la banda de paso se vería incrementado lógicamente el orden del filtro.
#
# Se concluye entonces que implementación diseñada satisface los requerimientos planteados por el enunciado.
