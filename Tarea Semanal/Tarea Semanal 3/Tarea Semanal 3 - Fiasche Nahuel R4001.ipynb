# %% [markdown]
# # Teoría de los Circuitos II - R4001  #
# # Tarea Semanal 3 - Fiasche Nahuel #

# %% [markdown]
# # Cálculo Analítico
# A continuación, se adjunta en formato PDF todos los cálculos analíticos, a saber:
# <ul>
#   <li>Cálculo de la Transferencia, en forma algebraica pura</li>
#   <li>Normalización de la Transferencia</li>
#   <li>Diagrama de Polos y Ceros</li>
#   <li>Bosquejo aproximado del módulo de la transferencia y de su respuesta en fase</li>
#   <li>Implementación de la Red (pasiva pura) Normalizada</li>
#   <li>Implementación de la Red (pasiva pura), pero con capacitores de 100 nF</li>
#   <li>Implementación de la Red utilizando un Ackerberg Mosberg, con capacitores de 100 nF</li>
#   <li>Cálculo de la Transferencia, usando la normalización "W butter"</li>
#
# </ul>

# %%
from IPython.display import IFrame
IFrame("./TS3.pdf", width=1000, height=900)
# Out:
#         <iframe
#             width="1000"
#             height="900"
#             src="./TS3.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# # Cálculo de las Raíces del Polinomio de Máxima Planicidad
# En el cálculo analítico, se utilizó el siguiente script para obtener las 3 raíces del polinomio de Máxima Planicidad

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on Sat Apr  8 13:48:47 2023

@author: nahu
"""

# Librerías externas NumPy, SciPy y Matplotlib
from scipy.signal import TransferFunction
import matplotlib.pyplot as plt
import numpy as np

from pytc2.sistemas_lineales import pzmap, GroupDelay, bodePlot

E = 0.5088
a = 1
b = 2*E**(-1/3)
c = 2*E**(-2/3)
d = 1/E

raices = np.roots([a,b,c,d])

# %% [markdown]
# # Simulación Numérica (Normalizada)

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on Mon May  1 14:30:37 2023

@author: nahu
"""

# Librerías externas NumPy, SciPy y Matplotlib
from scipy.signal import TransferFunction
import matplotlib.pyplot as plt
import numpy as np

from pytc2.sistemas_lineales import pzmap, GroupDelay, bodePlot

Tf = TransferFunction([1.96] , [1, 2.5, 3.14, 1.96])

bodePlot(Tf, fig_id=1)

pzmap(Tf, fig_id=2) 

GroupDelay(Tf, fig_id=3)
# Out:
# (3,
#  <Axes: title={'center': 'Group delay'}, xlabel='Angular frequency [rad/sec]', ylabel='Group Delay [sec]'>)

# %% [markdown]
# # Simulación Circuital de la Implementación Pasiva Normalizada
# La implementación pasiva a simular se adjunta a continuación.
#
# ![image.png](attachment:image.png)
#
# Las simulaciones obtenidas se encuentran a continuación.
#
# ![image-4.png](attachment:image-4.png)
#
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# # Simulación Circuital de la Implementación Pasiva Desnormalizada
# La implementación pasiva a simular se adjunta a continuación.
#
# ![image.png](attachment:image.png)
#
# Las simulaciones obtenidas se encuentran a continuación.
#
# ![image-4.png](attachment:image-4.png)
#
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# # Simulación Circuital de la Implementación Activa (Ackerberg Mosberg)
# La implementación activa a simular se adjunta a continuación.
#
# ![image.png](attachment:image.png)
#
# Las simulaciones obtenidas se encuentran a continuación
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# # Conclusiones
#
# Se observa que la respuesta de módulo de la transferencia normalizada, obtenida a partir de la simulación numérica, coincide con la simulada circuitalmente.
# También se destaca que en ambos implementaciones, las ganancias en 1.5 Khz y 3 Khz son -1 db y -12.66 db respectivamente, lo que verifica que el circuito hallado cumple con los requerimientos establecidos por la plantilla.
#
# Por otro lado, se destaca que el procedimiento para obtener la transferencia normalizada, utilizando la normalización respecto de la "W butter", resulta mucho más simple que el cálculo matemático puro. La pequeña diferencia de ganancia en continua de la transferencia obtenida con ambos metodos se debe simplemente a un error de redondeo.
#
# Se concluye entonces que las dos implementaciones diseñadas satisfacen los requerimientos planteados por el enunciado.
